# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('market.csv')
print(data.shape)
# Out:
# (1000, 17)

# %%
data=pd.read_csv("market.csv")
data.head()
# Out:
#     Invoice ID       City Customer type  Gender            Product line  \
# 0  750-67-8428     Yangon        Member  Female       Health and beauty
# 1  226-31-3081  Naypyitaw        Normal  Female  Electronic accessories
# 2  631-41-3108     Yangon        Normal    Male      Home and lifestyle
# 3  123-19-1176     Yangon        Member    Male       Health and beauty
# 4  373-73-7910     Yangon        Normal    Male       Sports and travel
#
#    Unit price  Quantity   Tax 5%     Total      Payment    cogs  \
# 0       74.69         7  26.1415  548.9715      Ewallet  522.83
# 1       15.28         5   3.8200   80.2200         Cash   76.40
# 2       46.33         7  16.2155  340.5255  Credit card  324.31
# 3       58.22         8  23.2880  489.0480      Ewallet  465.76
# 4       86.31         7  30.2085  634.3785      Ewallet  604.17
#
#    gross margin percentage  gross income  Rating
# 0                 4.761905       26.1415     9.1
# ...

# %%
data['Invoice ID']
# Out:
# 0      750-67-8428
# 1      226-31-3081
# 2      631-41-3108
# 3      123-19-1176
# 4      373-73-7910
#           ...
# 995    233-67-5758
# 996    303-96-2227
# 997    727-02-1313
# 998    347-56-2442
# 999    849-09-3807
# Name: Invoice ID, Length: 1000, dtype: object

# %%
data['Product line'].unique()
# Out:
# array(['Health and beauty', 'Electronic accessories',
#        'Home and lifestyle', 'Sports and travel', 'Food and beverages',
#        'Fashion accessories'], dtype=object)

# %%
data[data['Gender'] == "Male"]
# Out:
#       Invoice ID       City Customer type Gender            Product line  \
# 2    631-41-3108     Yangon        Normal   Male      Home and lifestyle
# 3    123-19-1176     Yangon        Member   Male       Health and beauty
# 4    373-73-7910     Yangon        Normal   Male       Sports and travel
# 5    699-14-3026  Naypyitaw        Normal   Male  Electronic accessories
# 11   529-56-3974   Mandalay        Member   Male  Electronic accessories
# ..           ...        ...           ...    ...                     ...
# 992  745-74-0715     Yangon        Normal   Male  Electronic accessories
# 993  690-01-6631   Mandalay        Normal   Male     Fashion accessories
# 995  233-67-5758  Naypyitaw        Normal   Male       Health and beauty
# 997  727-02-1313     Yangon        Member   Male      Food and beverages
# 998  347-56-2442     Yangon        Normal   Male      Home and lifestyle
#
#      Unit price  Quantity   Tax 5%     Total      Payment    cogs  \
# ...

# %%
data[data['Gender'] == "Female"].head()
# Out:
#     Invoice ID       City Customer type  Gender            Product line  \
# 0  750-67-8428     Yangon        Member  Female       Health and beauty
# 1  226-31-3081  Naypyitaw        Normal  Female  Electronic accessories
# 6  355-53-5943     Yangon        Member  Female  Electronic accessories
# 7  315-22-5665  Naypyitaw        Normal  Female      Home and lifestyle
# 8  665-32-9167     Yangon        Member  Female       Health and beauty
#
#    Unit price  Quantity   Tax 5%     Total      Payment    cogs  \
# 0       74.69         7  26.1415  548.9715      Ewallet  522.83
# 1       15.28         5   3.8200   80.2200         Cash   76.40
# 6       68.84         6  20.6520  433.6920      Ewallet  413.04
# 7       73.56        10  36.7800  772.3800      Ewallet  735.60
# 8       36.26         2   3.6260   76.1460  Credit card   72.52
#
#    gross margin percentage  gross income  Rating
# 0                 4.761905       26.1415     9.1
# ...

# %%
data.iloc[8]
# Out:
# Invoice ID                       665-32-9167
# City                                  Yangon
# Customer type                         Member
# Gender                                Female
# Product line               Health and beauty
# Unit price                             36.26
# Quantity                                   2
# Tax 5%                                 3.626
# Total                                 76.146
# Payment                          Credit card
# cogs                                   72.52
# gross margin percentage               4.7619
# gross income                           3.626
# Rating                                   7.2
# Name: 8, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   City                     1000 non-null   object
#  2   Customer type            1000 non-null   object
#  3   Gender                   1000 non-null   object
#  4   Product line             1000 non-null   object
#  5   Unit price               1000 non-null   float64
#  6   Quantity                 1000 non-null   int64
#  7   Tax 5%                   1000 non-null   float64
#  8   Total                    1000 non-null   float64
#  9   Payment                  1000 non-null   object
#  10  cogs                     1000 non-null   float64
#  11  gross margin percentage  1000 non-null   float64
#  12  gross income             1000 non-null   float64
#  13  Rating                   1000 non-null   float64
# ...

# %%
data[data['Total'] > 900]
# Out:
#       Invoice ID       City Customer type  Gender            Product line  \
# 70   393-65-2792  Naypyitaw        Normal    Male      Food and beverages
# 96   766-85-7061   Mandalay        Normal    Male       Health and beauty
# 105  704-48-3927     Yangon        Member    Male  Electronic accessories
# 122  219-22-9386   Mandalay        Member    Male       Sports and travel
# 140  731-81-9469  Naypyitaw        Member  Female       Sports and travel
# 141  280-17-4359  Naypyitaw        Member    Male       Health and beauty
# 158  743-04-1105   Mandalay        Member    Male       Health and beauty
# 166  234-65-2137  Naypyitaw        Normal    Male      Home and lifestyle
# 167  687-47-8271     Yangon        Normal    Male     Fashion accessories
# 209  817-69-8206   Mandalay        Normal  Female  Electronic accessories
# 350  860-79-0874  Naypyitaw        Member  Female     Fashion accessories
# 357  554-42-2417  Naypyitaw        Normal  Female       Sports and travel
# ...

# %%
data.query('100<Total>500')
# Out:
#       Invoice ID       City Customer type  Gender            Product line  \
# 0    750-67-8428     Yangon        Member  Female       Health and beauty
# 4    373-73-7910     Yangon        Normal    Male       Sports and travel
# 5    699-14-3026  Naypyitaw        Normal    Male  Electronic accessories
# 7    315-22-5665  Naypyitaw        Normal  Female      Home and lifestyle
# 14   829-34-3910     Yangon        Normal  Female       Health and beauty
# ..           ...        ...           ...     ...                     ...
# 988  267-62-7380  Naypyitaw        Member    Male  Electronic accessories
# 989  430-53-4718   Mandalay        Member    Male       Health and beauty
# 991  602-16-6955   Mandalay        Normal  Female       Sports and travel
# 996  303-96-2227   Mandalay        Normal  Female      Home and lifestyle
# 999  849-09-3807     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total      Payment    cogs  \
# ...

# %%
data.groupby('Gender').sum()
# Out:
#         Unit price  Quantity    Tax 5%       Total       cogs  \
# Gender
# Female    27687.24      2869  7994.425  167882.925  159888.50
# Male      27984.89      2641  7384.944  155083.824  147698.88
#
#         gross margin percentage  gross income  Rating
# Gender
# Female              2385.714286      7994.425  3489.2
# Male                2376.190476      7384.944  3483.5

# %%
data.groupby('City').min()
# Out:
#             Invoice ID Customer type  Gender            Product line  \
# City
# Mandalay   109-28-2512        Member  Female  Electronic accessories
# Naypyitaw  101-81-4070        Member  Female  Electronic accessories
# Yangon     101-17-6199        Member  Female  Electronic accessories
#
#            Unit price  Quantity  Tax 5%    Total Payment   cogs  \
# City
# Mandalay        10.59         1  0.8875  18.6375    Cash  17.75
# Naypyitaw       10.16         1  0.5085  10.6785    Cash  10.17
# Yangon          10.08         1  0.6045  12.6945    Cash  12.09
#
#            gross margin percentage  gross income  Rating
# City
# Mandalay                  4.761905        0.8875     4.0
# Naypyitaw                 4.761905        0.5085     4.0
# Yangon                    4.761905        0.6045     4.0

# %%
dff=data.groupby(['City', 'Payment'])
dff.first()
# Out:
#                         Invoice ID Customer type  Gender  \
# City      Payment
# Mandalay  Cash         529-56-3974        Member    Male
#           Credit card  692-92-5582        Member  Female
#           Ewallet      351-62-0822        Member  Female
# Naypyitaw Cash         226-31-3081        Normal  Female
#           Credit card  778-71-5554        Member    Male
#           Ewallet      699-14-3026        Normal    Male
# Yangon    Cash         829-34-3910        Normal  Female
#           Credit card  631-41-3108        Normal    Male
#           Ewallet      750-67-8428        Member  Female
#
#                                  Product line  Unit price  Quantity   Tax 5%  \
# City      Payment
# Mandalay  Cash         Electronic accessories       25.51         4   5.1020
#           Credit card      Food and beverages       54.84         3   8.2260
#           Ewallet         Fashion accessories       14.48         4   2.8960
# ...

# %%
dff= data.groupby(['City', 'Payment'])['Total'].sum()
dff
# Out:
# City       Payment
# Mandalay   Cash           35339.4615
#            Credit card    37344.8565
#            Ewallet        33513.3540
# Naypyitaw  Cash           43085.8575
#            Credit card    30327.4650
#            Ewallet        37155.3840
# Yangon     Cash           33781.2510
#            Credit card    33094.7505
#            Ewallet        39324.3690
# Name: Total, dtype: float64

# %%
dff = data.groupby(['City', 'Payment'],as_index=False)['Total'].sum()
dff
# Out:
#         City      Payment       Total
# 0   Mandalay         Cash  35339.4615
# 1   Mandalay  Credit card  37344.8565
# 2   Mandalay      Ewallet  33513.3540
# 3  Naypyitaw         Cash  43085.8575
# 4  Naypyitaw  Credit card  30327.4650
# 5  Naypyitaw      Ewallet  37155.3840
# 6     Yangon         Cash  33781.2510
# 7     Yangon  Credit card  33094.7505
# 8     Yangon      Ewallet  39324.3690

# %%
data.query('Payment=="Cash" & Gender=="Female" & Total > 900')
# Out:
#       Invoice ID       City Customer type  Gender        Product line  \
# 357  554-42-2417  Naypyitaw        Normal  Female   Sports and travel
# 611  277-35-5865  Naypyitaw        Member  Female  Food and beverages
# 959  384-59-6655     Yangon        Member  Female  Food and beverages
#
#      Unit price  Quantity   Tax 5%      Total Payment    cogs  \
# 357       95.44        10  47.7200  1002.1200    Cash  954.40
# 611       98.97         9  44.5365   935.2665    Cash  890.73
# 959       98.66         9  44.3970   932.3370    Cash  887.94
#
#      gross margin percentage  gross income  Rating
# 357                 4.761905       47.7200     5.2
# 611                 4.761905       44.5365     6.7
# 959                 4.761905       44.3970     8.4

# %%
City_list = data['City'].unique()
City_list
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
plt.bar(City_list,data.groupby(['City'])['Total'].sum())
plt.show()

# %%
gender=data['Gender'].unique()
gender
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
plt.bar(gender,data.groupby(['Gender']).Total.sum())
plt.show()

# %%
plt.pie(data.groupby(['City']).sum()["Total"], labels=City_list)
plt.show()

# %%
data.groupby(['City']).count()
# Out:
#            Invoice ID  Customer type  Gender  Product line  Unit price  \
# City
# Mandalay          332            332     332           332         332
# Naypyitaw         328            328     328           328         328
# Yangon            340            340     340           340         340
#
#            Quantity  Tax 5%  Total  Payment  cogs  gross margin percentage  \
# City
# Mandalay        332     332    332      332   332                      332
# Naypyitaw       328     328    328      328   328                      328
# Yangon          340     340    340      340   340                      340
#
#            gross income  Rating
# City
# Mandalay            332     332
# Naypyitaw           328     328
# Yangon              340     340

# %%
data.groupby(['City', 'Gender']).count()
# Out:
#                   Invoice ID  Customer type  Product line  Unit price  \
# City      Gender
# Mandalay  Female         162            162           162         162
#           Male           170            170           170         170
# Naypyitaw Female         178            178           178         178
#           Male           150            150           150         150
# Yangon    Female         161            161           161         161
#           Male           179            179           179         179
#
#                   Quantity  Tax 5%  Total  Payment  cogs  \
# City      Gender
# Mandalay  Female       162     162    162      162   162
#           Male         170     170    170      170   170
# Naypyitaw Female       178     178    178      178   178
#           Male         150     150    150      150   150
# Yangon    Female       161     161    161      161   161
#           Male         179     179    179      179   179
#
# ...

# %%
p=data.groupby(['City', 'Gender']).count()['Total']
p
# Out:
# City       Gender
# Mandalay   Female    162
#            Male      170
# Naypyitaw  Female    178
#            Male      150
# Yangon     Female    161
#            Male      179
# Name: Total, dtype: int64

# %%
p.plot(kind='bar')

# %%
s1=p.unstack(level=0)
s1.T
# Out:
# Gender     Female  Male
# City
# Mandalay      162   170
# Naypyitaw     178   150
# Yangon        161   179

# %%
s1.T.plot(kind = 'bar')

# %%
dff=data.groupby(['City','Payment']).count()['Rating']
dff.T
# Out:
# City       Payment
# Mandalay   Cash           110
#            Credit card    109
#            Ewallet        113
# Naypyitaw  Cash           124
#            Credit card     98
#            Ewallet        106
# Yangon     Cash           110
#            Credit card    104
#            Ewallet        126
# Name: Rating, dtype: int64

# %%
dff.unstack(level=0).T.plot(kind='bar')

# %%
dff=data.groupby(['City']).mean()['Rating']
dff.T
# Out:
# City
# Mandalay     6.818072
# Naypyitaw    7.072866
# Yangon       7.027059
# Name: Rating, dtype: float64

# %%
data.groupby(['City']).mean()['Rating'].T.plot(kind='pie')
plt.show()

# %%
data.groupby(['City', 'Gender']).count()['Rating'].T.unstack(level=0).plot(kind='bar')
plt.show()

# %%
data.groupby('Gender')['Total'].sum().T.plot(kind='bar')
plt.show()

# %%
data.groupby(['Product line', 'Gender']).sum()['Unit price']
# Out:
# Product line            Gender
# Electronic accessories  Female    4372.33
#                         Male      4731.44
# Fashion accessories     Female    5330.59
#                         Male      4842.76
# Food and beverages      Female    5408.13
#                         Male      4337.41
# Health and beauty       Female    3269.71
#                         Male      5068.17
# Home and lifestyle      Female    4522.16
#                         Male      4328.55
# Sports and travel       Female    4784.32
#                         Male      4676.56
# Name: Unit price, dtype: float64

# %%
data.groupby(['Product line', 'Gender']).sum()['Unit price'].unstack(level=0)
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Gender
# Female                       4372.33              5330.59             5408.13
# Male                         4731.44              4842.76             4337.41
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Gender
# Female                  3269.71             4522.16            4784.32
# Male                    5068.17             4328.55            4676.56

# %%
data.groupby(['Product line', 'Gender']).sum()['Unit price'].unstack(level=0).T.diff().hist()
plt.show()
